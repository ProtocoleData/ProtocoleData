# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
path = "D:/_Repository/Github/ProtocoleData/Data_contentieux_date.csv"
dataset = pd.read_csv(path, delimiter=";", low_memory=False )# Dataset is now stored in a Pandas Dataframe

# opsd_daily = pd.read_csv('C:/Users/Jupyter_Notebook/Data_contentieux.csv', error_bad_lines=False)

# %%
dataset.shape
# Out:
# (1048547, 23)

# %%
dataset.columns
# Out:
# Index(['juridiction', 'lieu', 'formation', 'requete', 'date', 'nom',
#        'demandeur', 'fondement', 'issue', 'urgence', 'doute_serieux', 'mort',
#        'espece_individu', 'euthanasie', 'conditions_de_vie', 'chasse',
#        'espece', 'qualification', 'securite', 'salubrite', 'protection',
#        'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
table_field = list(dataset.columns.values)
table_field
# Out:
# ['juridiction',
#  'lieu',
#  'formation',
#  'requete',
#  'date',
#  'nom',
#  'demandeur',
#  'fondement',
#  'issue',
#  'urgence',
#  'doute_serieux',
#  'mort',
#  'espece_individu',
#  'euthanasie',
#  'conditions_de_vie',
#  'chasse',
#  'espece',
#  'qualification',
#  'securite',
#  'salubrite',
#  'protection',
#  'Unnamed: 21',
#  'Unnamed: 22']

# %%
dataset['date']= pd.to_datetime(dataset['date'], dayfirst=True, errors='coerce')
dataset['requete']= pd.to_datetime(dataset['requete'], dayfirst=True, errors='coerce')

print(dataset)
# DatetimeIndex = dataset.set_index('Date')
# DatetimeIndex(dataset.Date, dtype='datetime64[ns]', freq=None)
# Out:
#         juridiction       lieu  formation    requete       date  \
# 0                CE        NaN  cassation 2001-02-23 2001-05-16
# 1                CE        NaN      ord.  2001-06-08 2001-07-09
# 2                CE        NaN      ord.  2001-07-13 2001-08-08
# 3                CE        NaN        NaN 2003-08-01 2004-01-14
# 4                CE        NaN        NaN 2004-08-13 2004-08-20
# 5                CE        NaN        NaN 2004-10-05 2004-10-28
# 6                CE        NaN      ord.  2004-10-29 2004-12-02
# 7                CE        NaN       ord. 2005-05-26 2005-06-10
# 8                CE        NaN        NaN 2005-06-24 2005-07-21
# 9                CE        NaN       ord. 2005-07-26 2005-08-03
# 10               CE        NaN       ord. 2006-02-01 2006-02-08
# 11               CE        NaN  cassation 2005-11-03 2006-03-15
# 12               CE        NaN        NaN        NaT 2006-05-09
# 13               CE        NaN      ord.  2007-01-23 2007-02-08
# 14               CE        NaN  cassation 2007-03-09 2007-06-05
# 15               CE        NaN  cassation 2008-03-04 2008-08-06
# 16               CE        NaN      ord.  2009-01-22 2009-02-02
# 17               TA   Toulouse       ord. 2009-09-02 2009-09-17
# 18               CE        NaN  cassation 2009-06-24 2009-10-23
# 19               TA    Mayotte        NaN 2010-11-30 2010-12-31
# 20               CE        NaN        NaN 2011-03-21 2011-04-21
# 21               TA   Grenoble       ord. 2011-05-20 2011-06-10
# 22               CE        NaN        NaN 2012-02-06 2012-02-08
# 23               CE        NaN        NaN 2012-02-06 2012-02-08
# 24               CE        NaN       ord. 2012-10-18 2012-11-16
# 25               CE        NaN  cassation 2012-12-21 2013-02-27
# 26               CE        NaN      ord.  2013-06-25 2013-07-05
# 27               CE        NaN  cassation 2013-03-14 2013-10-09
# 28               TA  Marseille       ord. 2013-10-04 2013-10-17
# 29               TA   Grenoble       ord. 2013-10-03 2013-10-18
# ...             ...        ...        ...        ...        ...
# 1048517         NaN        NaN        NaN        NaT        NaT
# 1048518         NaN        NaN        NaN        NaT        NaT
# 1048519         NaN        NaN        NaN        NaT        NaT
# 1048520         NaN        NaN        NaN        NaT        NaT
# 1048521         NaN        NaN        NaN        NaT        NaT
# 1048522         NaN        NaN        NaN        NaT        NaT
# 1048523         NaN        NaN        NaN        NaT        NaT
# 1048524         NaN        NaN        NaN        NaT        NaT
# 1048525         NaN        NaN        NaN        NaT        NaT
# 1048526         NaN        NaN        NaN        NaT        NaT
# 1048527         NaN        NaN        NaN        NaT        NaT
# 1048528         NaN        NaN        NaN        NaT        NaT
# 1048529         NaN        NaN        NaN        NaT        NaT
# 1048530         NaN        NaN        NaN        NaT        NaT
# 1048531         NaN        NaN        NaN        NaT        NaT
# 1048532         NaN        NaN        NaN        NaT        NaT
# 1048533         NaN        NaN        NaN        NaT        NaT
# 1048534         NaN        NaN        NaN        NaT        NaT
# 1048535         NaN        NaN        NaN        NaT        NaT
# 1048536         NaN        NaN        NaN        NaT        NaT
# 1048537         NaN        NaN        NaN        NaT        NaT
# 1048538         NaN        NaN        NaN        NaT        NaT
# 1048539         NaN        NaN        NaN        NaT        NaT
# 1048540         NaN        NaN        NaN        NaT        NaT
# 1048541         NaN        NaN        NaN        NaT        NaT
# 1048542         NaN        NaN        NaN        NaT        NaT
# 1048543         NaN        NaN        NaN        NaT        NaT
# 1048544         NaN        NaN        NaN        NaT        NaT
# 1048545         NaN        NaN        NaN        NaT        NaT
# 1048546         NaN        NaN        NaN        NaT        NaT
#
#                                                        nom  \
# 0                                            Epoux Duffaut
# 1        ass. fédérative régionale pour la protection d...
# 2                                                    BRARD
# 3                                                    ASPAS
# 4                                                    ASPAS
# 5                                  Société centrale canine
# 6                                         Mathilde Gombert
# 7                                                    ASPAS
# 8                                                    ASPAS
# 9                                                      LPO
# 10       Ass. Convention vie et nature pour une écologi...
# 11                                        GAEC de Beauplat
# 12       Féd. Transpyrénéenne des éleveurs de montagne ...
# 13                        Ass. France Nature Environnement
# 14                                                   ASPAS
# 15                   Commune de Ste-Maxime c. Fanny Guerin
# 16                                                   ASPAS
# 17                             Comité écologique ariégeois
# 18                               Sté Ferme de la Blaquière
# 19                               Association Terre d'Asile
# 20                        Fondation assistance aux animaux
# 21                                                   ASPAS
# 22                                                   ASPAS
# 23                                                   ASPAS
# 24                                                   ASPAS
# 25                                            Sté Promogil
# 26                                                   ASPAS
# 27                                  SEM Nièvre Aménagement
# 28                                                   ASPAS
# 29                                     ASPAS et LPO Drôme
# ...                                                    ...
# 1048517                                                NaN
# 1048518                                                NaN
# 1048519                                                NaN
# 1048520                                                NaN
# 1048521                                                NaN
# 1048522                                                NaN
# 1048523                                                NaN
# 1048524                                                NaN
# 1048525                                                NaN
# 1048526                                                NaN
# 1048527                                                NaN
# 1048528                                                NaN
# 1048529                                                NaN
# 1048530                                                NaN
# 1048531                                                NaN
# 1048532                                                NaN
# 1048533                                                NaN
# 1048534                                                NaN
# 1048535                                                NaN
# 1048536                                                NaN
# 1048537                                                NaN
# 1048538                                                NaN
# 1048539                                                NaN
# 1048540                                                NaN
# 1048541                                                NaN
# 1048542                                                NaN
# 1048543                                                NaN
# 1048544                                                NaN
# 1048545                                                NaN
# 1048546                                                NaN
#
#                             demandeur             fondement       issue  \
# 0                          administré  article L. 521-1 CJA  Suspension
# 1                    ass. spécialisée  article L. 521-1 CJA      Rejet
# 2                         administré   article L. 521-1 CJA       Rejet
# 3                      ass. nationale  article L. 521-1 CJA       Rejet
# 4                      ass. nationale  article L. 521-1 CJA       Rejet
# 5                      ass. nationale  article L. 521-1 CJA       Rejet
# 6                          administré  article L. 521-1 CJA       Rejet
# 7                      ass. nationale  article L. 521-1 CJA  Suspension
# 8                      ass. nationale  article L. 521-1 CJA       Rejet
# 9                      ass. nationale  article L. 521-1 CJA  Suspension
# 10                     ass. nationale  article L. 521-1 CJA  Suspension
# 11                         administré  article L. 521-1 CJA       Rejet
# 12                   ass. spécialisée  article L. 521-1 CJA       Rejet
# 13                     ass. nationale  article L. 521-1 CJA       Rejet
# 14                     ass. nationale  article L. 521-1 CJA       Rejet
# 15                         administré  article L. 521-1 CJA  Suspension
# 16                     ass. nationale  article L. 521-1 CJA  Suspension
# 17                   ass. spécialisée  article L. 521-1 CJA  Suspension
# 18                         administré  article L. 521-1 CJA       Rejet
# 19                    ass. nationale?  article L. 521-1 CJA       Rejet
# 20                   ass. spécialisée  article L. 521-1 CJA       Rejet
# 21                     ass. nationale  article L. 521-1 CJA  Suspension
# 22                     ass. nationale  article L. 521-1 CJA       Rejet
# 23                     ass. nationale  article L. 521-1 CJA       Rejet
# 24                     ass. nationale  article L. 521-1 CJA       Rejet
# 25                         administré  article L. 521-1 CJA  Suspension
# 26                     ass. nationale  article L. 521-1 CJA       Rejet
# 27                         administré  article L. 521-1 CJA  Suspension
# 28                     ass. nationale  article L. 521-1 CJA  Suspension
# 29       ass. nationale + spécialisée  article L. 521-1 CJA  Suspension
# ...                               ...                   ...         ...
# 1048517                           NaN                   NaN         NaN
# 1048518                           NaN                   NaN         NaN
# 1048519                           NaN                   NaN         NaN
# 1048520                           NaN                   NaN         NaN
# 1048521                           NaN                   NaN         NaN
# 1048522                           NaN                   NaN         NaN
# 1048523                           NaN                   NaN         NaN
# 1048524                           NaN                   NaN         NaN
# 1048525                           NaN                   NaN         NaN
# 1048526                           NaN                   NaN         NaN
# 1048527                           NaN                   NaN         NaN
# 1048528                           NaN                   NaN         NaN
# 1048529                           NaN                   NaN         NaN
# 1048530                           NaN                   NaN         NaN
# 1048531                           NaN                   NaN         NaN
# 1048532                           NaN                   NaN         NaN
# 1048533                           NaN                   NaN         NaN
# 1048534                           NaN                   NaN         NaN
# 1048535                           NaN                   NaN         NaN
# 1048536                           NaN                   NaN         NaN
# 1048537                           NaN                   NaN         NaN
# 1048538                           NaN                   NaN         NaN
# 1048539                           NaN                   NaN         NaN
# 1048540                           NaN                   NaN         NaN
# 1048541                           NaN                   NaN         NaN
# 1048542                           NaN                   NaN         NaN
# 1048543                           NaN                   NaN         NaN
# 1048544                           NaN                   NaN         NaN
# 1048545                           NaN                   NaN         NaN
# 1048546                           NaN                   NaN         NaN
#
#          urgence    ...     conditions_de_vie chasse                   espece  \
# 0            Oui    ...                   Non    Non                   Bovins
# 1            Non    ...                   Oui    Non  Oiseaux et gibier d'eau
# 2        Silence    ...                   Non    Oui                    Loups
# 3            Non    ...                   Non    Oui  Ragondins et rat musqué
# 4        Inutile    ...                   Non    Oui                    Loups
# 5            Non    ...                   Oui    Non                   Chiens
# 6            Non    ...                   Oui    Non                   Chiens
# 7            Oui    ...                   Non    Oui                    Loups
# 8        Inutile    ...                   Non    Oui                    Loups
# 9            Oui    ...                   Non    Oui  Oiseaux et gibier d'eau
# 10           Oui    ...                   Non    Oui  Oiseaux et gibier d'eau
# 11           Non    ...                   Non    Non                   Bovins
# 12           Oui    ...                   Oui    Non                   Divers
# 13           Non    ...                   Non    Oui  Oiseaux et gibier d'eau
# 14           Non    ...                   Non    Oui  Oiseaux et gibier d'eau
# 15           Oui    ...                   Non    Non                   Chiens
# 16           Oui    ...                   Non    Oui  Oiseaux et gibier d'eau
# 17           Oui    ...                   Non    Oui  Oiseaux et gibier d'eau
# 18           Non    ...                   Non    Non               Dromadaire
# 19           Non    ...                   Oui    Non                Lémuriens
# 20           Non    ...                   Oui    Non                   Divers
# 21           Oui    ...                   Non    Oui                    Loups
# 22       Inutile    ...                   Non    Oui  Oiseaux et gibier d'eau
# 23           Non    ...                   Non    Oui  Oiseaux et gibier d'eau
# 24       Inutile    ...                   Non    Oui                   Divers
# 25           Oui    ...                   Non    Non                 Eléphant
# 26           Non    ...                   Non    Oui  Oiseaux et gibier d'eau
# 27           Oui    ...                   Non    Non                   Divers
# 28           Oui    ...                   Oui    Non                    Loups
# 29           Oui    ...                   Non    Non                    Loups
# ...          ...    ...                   ...    ...                      ...
# 1048517      NaN    ...                   NaN    NaN                      NaN
# 1048518      NaN    ...                   NaN    NaN                      NaN
# 1048519      NaN    ...                   NaN    NaN                      NaN
# 1048520      NaN    ...                   NaN    NaN                      NaN
# 1048521      NaN    ...                   NaN    NaN                      NaN
# 1048522      NaN    ...                   NaN    NaN                      NaN
# 1048523      NaN    ...                   NaN    NaN                      NaN
# 1048524      NaN    ...                   NaN    NaN                      NaN
# 1048525      NaN    ...                   NaN    NaN                      NaN
# 1048526      NaN    ...                   NaN    NaN                      NaN
# 1048527      NaN    ...                   NaN    NaN                      NaN
# 1048528      NaN    ...                   NaN    NaN                      NaN
# 1048529      NaN    ...                   NaN    NaN                      NaN
# 1048530      NaN    ...                   NaN    NaN                      NaN
# 1048531      NaN    ...                   NaN    NaN                      NaN
# 1048532      NaN    ...                   NaN    NaN                      NaN
# 1048533      NaN    ...                   NaN    NaN                      NaN
# 1048534      NaN    ...                   NaN    NaN                      NaN
# 1048535      NaN    ...                   NaN    NaN                      NaN
# 1048536      NaN    ...                   NaN    NaN                      NaN
# 1048537      NaN    ...                   NaN    NaN                      NaN
# 1048538      NaN    ...                   NaN    NaN                      NaN
# 1048539      NaN    ...                   NaN    NaN                      NaN
# 1048540      NaN    ...                   NaN    NaN                      NaN
# 1048541      NaN    ...                   NaN    NaN                      NaN
# 1048542      NaN    ...                   NaN    NaN                      NaN
# 1048543      NaN    ...                   NaN    NaN                      NaN
# 1048544      NaN    ...                   NaN    NaN                      NaN
# 1048545      NaN    ...                   NaN    NaN                      NaN
# 1048546      NaN    ...                   NaN    NaN                      NaN
#
#         qualification securite salubrite protection Unnamed: 21 Unnamed: 22  \
# 0               Rente      Non       Oui        Non         NaN         NaN
# 1             Sauvage      Non       Non        Oui         NaN         NaN
# 2             Sauvage      Oui       Non        Oui         NaN         NaN
# 3             Sauvage      Non       Non        Non         NaN         NaN
# 4             Sauvage      Oui       Non        Oui         NaN         NaN
# 5          Domestique      Non       Oui        Non         NaN         NaN
# 6          Domestique      Non       Oui        Non         NaN         NaN
# 7             Sauvage      Oui       Non        Oui         NaN         NaN
# 8             Sauvage      Oui       Non        Oui         NaN         NaN
# 9             Sauvage      Non       Non        Oui         NaN         NaN
# 10            Sauvage      Non       Non        Oui         NaN         NaN
# 11              Rente      Non       Oui        Non         NaN         NaN
# 12              Rente      Non       Non        Non         NaN         NaN
# 13            Sauvage      Non       Non        Oui         NaN         NaN
# 14            Sauvage      Non       Non        Oui         NaN         NaN
# 15        Domestique       Oui       Non        Non         NaN         NaN
# 16            Sauvage      Non       Non        Oui         NaN         NaN
# 17            Sauvage      Non       Non        Oui         NaN         NaN
# 18          Spectacle      Non       Oui        Non         NaN         NaN
# 19            Sauvage      Non       Non        Oui         NaN         NaN
# 20               Tous      Non       Oui        Non         NaN         NaN
# 21            Sauvage      Oui       Non        Oui         NaN         NaN
# 22            Sauvage      Non       Non        Oui         NaN         NaN
# 23            Sauvage      Non       Non        Oui         NaN         NaN
# 24            Sauvage      Oui       Non        Oui         NaN         NaN
# 25          Spectacle      Non       Oui        Oui         NaN         NaN
# 26            Sauvage      Non       Non        Oui         NaN         NaN
# 27            Sauvage      Non       Non        Oui         NaN         NaN
# 28            Sauvage      Oui       Non        Oui         NaN         NaN
# 29            Sauvage      Oui       Non        Oui         NaN         NaN
# ...               ...      ...       ...        ...         ...         ...
# 1048517           NaN      NaN       NaN        NaN         NaN         NaN
# 1048518           NaN      NaN       NaN        NaN         NaN         NaN
# 1048519           NaN      NaN       NaN        NaN         NaN         NaN
# 1048520           NaN      NaN       NaN        NaN         NaN         NaN
# 1048521           NaN      NaN       NaN        NaN         NaN         NaN
# 1048522           NaN      NaN       NaN        NaN         NaN         NaN
# 1048523           NaN      NaN       NaN        NaN         NaN         NaN
# 1048524           NaN      NaN       NaN        NaN         NaN         NaN
# 1048525           NaN      NaN       NaN        NaN         NaN         NaN
# 1048526           NaN      NaN       NaN        NaN         NaN         NaN
# 1048527           NaN      NaN       NaN        NaN         NaN         NaN
# 1048528           NaN      NaN       NaN        NaN         NaN         NaN
# 1048529           NaN      NaN       NaN        NaN         NaN         NaN
# 1048530           NaN      NaN       NaN        NaN         NaN         NaN
# 1048531           NaN      NaN       NaN        NaN         NaN         NaN
# 1048532           NaN      NaN       NaN        NaN         NaN         NaN
# 1048533           NaN      NaN       NaN        NaN         NaN         NaN
# 1048534           NaN      NaN       NaN        NaN         NaN         NaN
# 1048535           NaN      NaN       NaN        NaN         NaN         NaN
# 1048536           NaN      NaN       NaN        NaN         NaN         NaN
# 1048537           NaN      NaN       NaN        NaN         NaN         NaN
# 1048538           NaN      NaN       NaN        NaN         NaN         NaN
# 1048539           NaN      NaN       NaN        NaN         NaN         NaN
# 1048540           NaN      NaN       NaN        NaN         NaN         NaN
# 1048541           NaN      NaN       NaN        NaN         NaN         NaN
# 1048542           NaN      NaN       NaN        NaN         NaN         NaN
# 1048543           NaN      NaN       NaN        NaN         NaN         NaN
# 1048544           NaN      NaN       NaN        NaN         NaN         NaN
# 1048545           NaN      NaN       NaN        NaN         NaN         NaN
# 1048546           NaN      NaN       NaN        NaN         NaN         NaN
#
#                dat
# 0       2001-05-16
# 1       2001-07-09
# 2       2001-08-08
# 3       2004-01-14
# 4       2004-08-20
# 5       2004-10-28
# 6       2004-12-02
# 7       2005-06-10
# 8       2005-07-21
# 9       2005-08-03
# 10      2006-02-08
# 11      2006-03-15
# 12      2006-05-09
# 13      2007-02-08
# 14      2007-06-05
# 15      2008-08-06
# 16      2009-02-02
# 17      2009-09-17
# 18      2009-10-23
# 19      2010-12-31
# 20      2011-04-21
# 21      2011-06-10
# 22      2012-02-08
# 23      2012-02-08
# 24      2012-11-16
# 25      2013-02-27
# 26      2013-07-05
# 27      2013-10-09
# 28      2013-10-17
# 29      2013-10-18
# ...            ...
# 1048517        NaT
# 1048518        NaT
# 1048519        NaT
# 1048520        NaT
# 1048521        NaT
# 1048522        NaT
# 1048523        NaT
# 1048524        NaT
# 1048525        NaT
# 1048526        NaT
# 1048527        NaT
# 1048528        NaT
# 1048529        NaT
# 1048530        NaT
# 1048531        NaT
# 1048532        NaT
# 1048533        NaT
# 1048534        NaT
# 1048535        NaT
# 1048536        NaT
# 1048537        NaT
# 1048538        NaT
# 1048539        NaT
# 1048540        NaT
# 1048541        NaT
# 1048542        NaT
# 1048543        NaT
# 1048544        NaT
# 1048545        NaT
# 1048546        NaT
#
# [1048547 rows x 24 columns]

# %%
dataset.dtypes
#pd.to_datetime(dataset['Date'], dayfirst=True)
# Out:
# juridiction                  object
# lieu                         object
# formation                    object
# requete              datetime64[ns]
# date                 datetime64[ns]
# nom                          object
# demandeur                    object
# fondement                    object
# issue                        object
# urgence                      object
# doute_serieux                object
# mort                         object
# espece_individu              object
# euthanasie                   object
# conditions_de_vie            object
# chasse                       object
# espece                       object
# qualification                object
# securite                     object
# salubrite                    object
# protection                   object
# Unnamed: 21                 float64
# Unnamed: 22                 float64
# dat                  datetime64[ns]
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
dataset = dataset.set_index('date')

dataset.index
#dataset['date'].plot(linewidth=0.5);
# , 'requete'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-760041ba0ec5> in <module>()
# ----> 1 dataset = dataset.set_index('date')
#       2
#       3 dataset.index
#       4 #dataset['date'].plot(linewidth=0.5);
#       5 # , 'requete'
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# D:\Program_Files\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'

# %%
# Importer les librairies

#librairie pandas
# 
import pandas as pd
#scikit-learn
import sklearn
#librairie numpy
import numpy
#librairie matplotlib
import matplotlib.pyplot

import seaborn as sns

# %%
# Importer le dataset

#dataset = pd.read_excel("exercice.xlsx",sheet_name=0,header=0,index_col=0)
dataset = pd.read_csv('Mall_Customers.csv')

# %%
#Rapide résumé du dataframe: nombre de colonnes et nombre de lignes

#nombre d'observations
n = dataset.shape[0]
#nombre de variables
p = dataset.shape[1]

print("Nombre de tuples: "+ str(n))
print("Nombre de colonnes: "+ str(p))

#Rapide résumé du dataframe: nombre de colonnes et nombre de lignes
dataset.shape
# Out:
# Nombre de tuples: 200
# Nombre de colonnes: 5
# (200, 5)

# %%
# Sélection des données (facultatif)
# dataset = dataset.iloc[:, 2:4].values

# %%
# Visualiser les premières lignes
dataset.head(20)

# %%
# Type des colonnes
dataset.dtypes

# %%
# Connaitre le nom des colonnes
dataset.columns

# %%
# removing null values to avoid errors  
# dataset.dropna(inplace = True)

# %%
# Visualiser plusieurs types de représentations selon une variable cible
import seaborn as sns

sns.pairplot(dataset,hue='Genre')
# Out:
# D:\Program_Files\Anaconda\envs\Full_install_clean\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Importer les librairies

#librairie pandas
import pandas as pandas
#scikit-learn
import sklearn
#librairie numpy
import numpy
#librairie matplotlib
import matplotlib.pyplot

# %%
# Importer le dataset

dataset = pandas.read_excel("Jusdorange_ACP.xlsx",sheet_name=0,header=0,index_col=0)

# %%
#Rapide résumé du dataframe: nombre de colonnes et nombre de lignes

#nombre d'observations
n = dataset.shape[0]
#nombre de variables
p = dataset.shape[1]

print("Nombre de tuples: "+ str(n))
print("Nombre de colonnes: "+ str(p))

#Rapide résumé du dataframe: nombre de colonnes et nombre de lignes
dataset.shape
# Out:
# Nombre de tuples: 6
# Nombre de colonnes: 16
# (6, 16)

# %%
dataset.head()
# Out:
#                 Odour intensity  Odour typicality  Pulpiness  Intensity gout  \
# Product
# Pampryl amb.               2.82              2.53       1.66            3.46
# Tropicana amb.             2.76              2.82       1.91            3.23
# Fruvita fr.                2.83              2.88       4.00            3.45
# Joker amb.                 2.76              2.59       1.66            3.37
# Tropicana fr.              3.20              3.02       3.69            3.12
#
#                 Acidity  amertume  douceur  Glucose  Fructose  Saccharose  \
# Product
# Pampryl amb.       3.15      2.97     2.60    25.32     27.36       36.45
# Tropicana amb.     2.55      2.08     3.32    17.33     20.00       44.15
# Fruvita fr.        2.42      1.76     3.38    23.65     25.65       52.12
# Joker amb.         3.05      2.56     2.80    32.42     34.54       22.92
# Tropicana fr.      2.33      1.97     3.34    22.70     25.32       45.80
#
#                 pouvoir douceur    pH  Citric acid  Vitamin C  \
# Product
# Pampryl amb.              89.95  3.59         0.84      43.44
# Tropicana amb.            82.55  3.89         0.67      32.70
# Fruvita fr.              102.22  3.85         0.69      37.00
# Joker amb.                90.71  3.60         0.95      36.60
# Tropicana fr.             94.87  3.82         0.71      39.50
#
#                Way of preserving   Origin
# Product
# Pampryl amb.             Ambient    Other
# Tropicana amb.           Ambient  Florida
# Fruvita fr.                Fresh  Florida
# Joker amb.               Ambient    Other
# Tropicana fr.              Fresh  Florida

# %%
# Corrélation 
dataset.corr()
# Out:
#                   Odour intensity  Odour typicality  Pulpiness  \
# Odour intensity          1.000000          0.582269   0.656364
# Odour typicality         0.582269          1.000000   0.767622
# Pulpiness                0.656364          0.767622   1.000000
# Intensity gout          -0.267904         -0.616998  -0.020079
# Acidity                 -0.145138         -0.837846  -0.468206
# amertume                -0.153850         -0.877538  -0.643804
# douceur                  0.233219          0.923100   0.629746
# Glucose                 -0.045471         -0.569755  -0.170526
# Fructose                -0.021296         -0.554612  -0.172727
# Saccharose               0.303847          0.756643   0.717681
# pouvoir douceur          0.413623          0.317869   0.824331
# pH                       0.138473          0.853769   0.514651
# Citric acid             -0.344568         -0.778161  -0.622281
# Vitamin C               -0.147400         -0.136777  -0.219808
#
#                   Intensity gout   Acidity  amertume   douceur   Glucose  \
# Odour intensity        -0.267904 -0.145138 -0.153850  0.233219 -0.045471
# Odour typicality       -0.616998 -0.837846 -0.877538  0.923100 -0.569755
# Pulpiness              -0.020079 -0.468206 -0.643804  0.629746 -0.170526
# Intensity gout          1.000000  0.727489  0.513782 -0.568617  0.485985
# Acidity                 0.727489  1.000000  0.913704 -0.900574  0.629086
# amertume                0.513782  0.913704  1.000000 -0.975686  0.524260
# douceur                -0.568617 -0.900574 -0.975686  1.000000 -0.659941
# Glucose                 0.485985  0.629086  0.524260 -0.659941  1.000000
# Fructose                0.457646  0.626810  0.522037 -0.652545  0.998867
# Saccharose             -0.196375 -0.688190 -0.713495  0.768802 -0.762668
# pouvoir douceur         0.386121 -0.115618 -0.306257  0.196582  0.314378
# pH                     -0.537640 -0.854262 -0.903899  0.966194 -0.819369
# Citric acid             0.277149  0.611876  0.679248 -0.795600  0.852299
# Vitamin C              -0.265617 -0.256259  0.091113 -0.179765  0.023660
#
#                   Fructose  Saccharose  pouvoir douceur        pH  \
# Odour intensity  -0.021296    0.303847         0.413623  0.138473
# Odour typicality -0.554612    0.756643         0.317869  0.853769
# Pulpiness        -0.172727    0.717681         0.824331  0.514651
# Intensity gout    0.457646   -0.196375         0.386121 -0.537640
# Acidity           0.626810   -0.688190        -0.115618 -0.854262
# amertume          0.522037   -0.713495        -0.306257 -0.903899
# douceur          -0.652545    0.768802         0.196582  0.966194
# Glucose           0.998867   -0.762668         0.314378 -0.819369
# Fructose          1.000000   -0.775085         0.296406 -0.814352
# Saccharose       -0.775085    1.000000         0.373593  0.818796
# pouvoir douceur   0.296406    0.373593         1.000000  0.036695
# pH               -0.814352    0.818796         0.036695  1.000000
# Citric acid       0.851339   -0.928619        -0.149466 -0.880909
# Vitamin C         0.005388   -0.029562        -0.028209 -0.204769
#
#                   Citric acid  Vitamin C
# Odour intensity     -0.344568  -0.147400
# Odour typicality    -0.778161  -0.136777
# Pulpiness           -0.622281  -0.219808
# Intensity gout       0.277149  -0.265617
# Acidity              0.611876  -0.256259
# amertume             0.679248   0.091113
# douceur             -0.795600  -0.179765
# Glucose              0.852299   0.023660
# Fructose             0.851339   0.005388
# Saccharose          -0.928619  -0.029562
# pouvoir douceur     -0.149466  -0.028209
# pH                  -0.880909  -0.204769
# Citric acid          1.000000   0.307276
# Vitamin C            0.307276   1.000000

# %%
if dataset.corr() < 0.5:
    data_corr = dataset.corr() 

data_corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-96ca04e9884b> in <module>
# ----> 1 if dataset.corr() < 0.5:
#       2     data_corr = dataset.corr()
#       3
#       4 data_corr
#
# D:\Program_Files\Anaconda\envs\Full_install_clean\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

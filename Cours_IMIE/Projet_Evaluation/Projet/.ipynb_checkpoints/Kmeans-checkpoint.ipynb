# %%
# K-Means

# Importer les librairies utiles
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importer le dataset + selection des variables numériques => la kmeans se fait plus avec des variables numeriques
dataset = pd.read_excel('Etats_Americains.xlsx', sheet_name='etats_americains')
X = dataset.iloc[:, 2:4].values
#X = dataset.iloc[:, 2:5].values

# %%
# Utiliser la méthode elbow (= methode du coude) pour trouver le nombre optimal de clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('La méthode Elbow')
plt.xlabel('Nombre de clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Construction du modèle : on tente une typologie à 4 classes
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %%
# Visualiser les résultats via un nuage de points
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], c = 'magenta', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], c = 'red', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], c = 'blue', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], c = 'green', label = 'Cluster 4')
#plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], c = 'cyan', label = 'Cluster 5')

plt.title('Clusters des Etats')
plt.xlabel('Salaire annuel')
plt.ylabel('Spending Score')
plt.legend()

# %%
# on recupere la classe des groupes, on l'ajoute à notre jeu de données puis on decrit les classes
labels2 = kmeans.predict(X)
dataset['cluster1'] = labels2
segments = dataset.groupby('cluster1')
segments.describe()
# Out:
#          Américains_migrants_avec_letranger                                \
#                                       count      mean       std       min
# cluster1
# 0                                      10.0 -0.036998  0.026274 -0.077232
# 1                                      17.0 -0.049579  0.041547 -0.168621
# 2                                       1.0 -0.031338       NaN -0.031338
# 3                                      23.0 -0.042782  0.073720 -0.293205
#
#                                                  Immigration_domestique_nette  \
#                25%       50%       75%       max                        count
# cluster1
# 0        -0.051682 -0.036370 -0.016713 -0.000684                         10.0
# 1        -0.071446 -0.040193 -0.024093 -0.001631                         17.0
# 2        -0.031338 -0.031338 -0.031338 -0.031338                          1.0
# 3        -0.045748 -0.018467 -0.003606 -0.000555                         23.0
#
#                        ...     Taux_de_naissance            Taux_mortalité  \
#                mean    ...                   75%        max          count
# cluster1               ...
# 0         -7.709143    ...             14.854913  20.405862           10.0
# 1          6.161954    ...             14.846203  16.856117           17.0
# 2         27.349466    ...             14.220773  14.220773            1.0
# 3         -1.846968    ...             14.213016  15.984093           23.0
#
#                                                                        \
#               mean       std       min       25%       50%        75%
# cluster1
# 0         8.765341  1.423236  5.519456  8.511582  9.124313   9.385172
# 1         8.323508  1.040741  6.263420  7.752941  8.297434   8.945590
# 2         7.167839       NaN  7.167839  7.167839  7.167839   7.167839
# 3         9.088857  1.547676  4.644884  8.647746  9.193188  10.023166
#
#
#                 max
# cluster1
# 0         10.763839
# 1         10.128311
# 2          7.167839
# 3         11.895671
#
# [4 rows x 64 columns]

# %%
# Affichage de la matrice envoyée dans la kmeans juste pour verification
print(X)
# Out:
# [[-1.78435591e+00 -2.19516544e-02]
#  [-1.71840250e+00 -2.39410797e-01]
#  [ 1.42506657e+01 -3.39153522e-02]
#  [ 3.58086097e-01 -1.33725098e-02]
#  [-2.01439779e+00 -4.39116052e-02]
#  [ 9.31794136e+00 -5.72694384e-02]
#  [-2.36549634e+00 -1.75178697e-02]
#  [ 5.39335439e+00 -4.01926736e-02]
#  [-7.77164922e+00 -7.34494301e-02]
#  [ 1.25211364e+01 -3.47024962e-02]
#  [ 7.06829685e+00 -7.14463350e-02]
#  [-2.49918736e+00 -2.93205314e-01]
#  [ 6.40193913e+00 -2.64949591e-02]
#  [-7.27510096e+00 -1.62630271e-02]
#  [-1.99468661e+00 -9.81234704e-04]
#  [-5.68182790e+00 -6.84186634e-04]
#  [-6.36299975e+00 -5.23260798e-02]
#  [ 1.51516791e-01 -5.80486408e-02]
#  [-7.98467337e+00 -3.53829306e-02]
#  [ 6.61630410e+00 -2.40932018e-02]
#  [ 2.18021579e+00 -5.52542103e-02]
#  [-3.25286269e+00 -5.32973503e-03]
#  [-2.70198123e+00 -1.60147063e-03]
#  [ 6.54024078e-01 -2.81560181e-03]
#  [-3.11473397e+00 -4.75852414e-02]
#  [-2.52233376e-02 -2.18483839e-02]
#  [-1.73368287e+00 -2.98529576e-02]
#  [-6.55776937e+00 -3.73562296e-02]
#  [ 2.73494664e+01 -3.13379302e-02]
#  [ 1.08046421e+01 -4.76500201e-03]
#  [-3.63760398e+00 -8.95758360e-03]
#  [-5.46921897e+00 -4.97499926e-02]
#  [-1.07764414e+01 -9.46801436e-03]
#  [ 5.42616000e+00 -1.00656367e-01]
#  [-1.34825864e+01 -7.72324919e-02]
#  [-3.69040741e+00 -4.39616826e-03]
#  [-3.21378273e+00 -6.18479771e-02]
#  [ 5.15798618e+00 -3.74330488e-03]
#  [-1.92086855e+00 -2.44157514e-03]
#  [ 3.65466702e+00 -2.26646017e-02]
#  [ 4.01795614e+00 -7.75287096e-02]
#  [-3.43774782e+00 -3.43642612e-02]
#  [ 1.50417568e+00 -1.84668314e-02]
#  [ 2.94189670e+00 -4.57209462e-02]
#  [-5.72916690e+00 -1.80633530e-02]
#  [ 2.78099463e+00 -1.63108190e-03]
#  [ 2.54586494e+00 -1.68620597e-01]
#  [ 3.67319626e+00 -7.41486309e-02]
#  [-2.46515376e+00 -5.54964826e-04]
#  [ 5.50546418e-01 -9.25599224e-04]
#  [-4.12804421e+00 -5.46091100e-02]]

# %%
# Test d'une 2eme technique permettant de choisir le nombre de classe : dendrogramme pour trouver le nb optimal de classes
plt.figure(1)
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()
plt.savefig('foo1.png')

# %%
# 2eme test de realisation d'une kmeans
clustering_method = KMeans(n_clusters = 3, random_state = 9999)
clustering_method.fit(X)
labels = clustering_method.predict(X)

# %%
# Affecter la classe au jeu de données
dataset['cluster'] = labels

# %%
segments = dataset.groupby('cluster')

# %%
segments.describe()
# Out:
#         Américains_migrants_avec_letranger                                \
#                                      count      mean       std       min
# cluster
# 0                                     27.0 -0.045870  0.068043 -0.293205
# 1                                      4.0 -0.026180  0.014349 -0.034702
# 2                                     20.0 -0.044247  0.041198 -0.168621
#
#                                                 Immigration_domestique_nette  \
#               25%       50%       75%       max                        count
# cluster
# 0       -0.051038 -0.029853 -0.007144 -0.000555                         27.0
# 1       -0.034112 -0.032627 -0.024695 -0.004765                          4.0
# 2       -0.061398 -0.033344 -0.017193 -0.000926                         20.0
#
#                    ...  Taux_mortalité            cluster1            \
#               mean ...             75%        max    count      mean
# cluster            ...
# 0        -4.546846 ...        9.725720  11.895671     27.0  1.888889
# 1        16.231478 ...        8.407921  10.128311      4.0  1.250000
# 2         3.518495 ...        9.681768  10.507078     20.0  1.600000
#
#
#               std  min  25%  50%   75%  max
# cluster
# 0        1.476309  0.0  0.0  3.0  3.00  3.0
# 1        0.500000  1.0  1.0  1.0  1.25  2.0
# 2        0.940325  1.0  1.0  1.0  3.00  3.0
#
# [3 rows x 72 columns]
